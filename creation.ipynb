# %%
import os

# Base path
BASE_PATH = os.getcwd()  # /path/to/llm-failure-eval

# Create directory structure
dirs = [
    "src/generators",
    "src/evaluators", 
    "src/models",
    "experiments/configs",
    "notebooks",
    "data/raw",
    "data/processed",
    "results/metrics",
    "results/visualizations",
    "tests"
]

for d in dirs:
    os.makedirs(d, exist_ok=True)
    # Create __init__.py for Python packages
    if d.startswith("src") or d == "tests":
        open(f"{d}/__init__.py", 'a').close()

# Create key files
files = [
    "README.md",
    "requirements.txt",
    ".gitignore",
    "src/config.py",
    "src/utils.py",
    "src/generators/contradictory_context.py",
    "src/generators/response_variance.py",
    "src/evaluators/consistency_scorer.py",
    "src/evaluators/contradiction_detector.py",
    "src/models/hf_client.py",
    "experiments/run_evaluation.py",
    "experiments/configs/experiment_config.yaml",
    "notebooks/analysis.ipynb",
    "tests/test_generators.py"
]

for f in files:
    open(f, 'a').close()

print(f"✅ Structure created at: {BASE_PATH}")
# Out:
# ✅ Structure created at: /Users/yasarmulani/Desktop/PhD 2027/Projects/llm-failure-eval
